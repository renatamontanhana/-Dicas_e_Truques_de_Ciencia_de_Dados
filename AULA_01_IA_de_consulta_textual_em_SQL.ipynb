# %% [markdown]
# <a href="https://colab.research.google.com/github/renatamontanhana/-Dicas_e_Truques_de_Ciencia_de_Dados/blob/main/AULA_01_IA_de_consulta_textual_em_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTK4gQ9nhwHHaSXMHpeggWg7twwMCgb877smkRmtkmDeDoGF9Z6&usqp=CAU)

# %% [markdown]
# # <font color='BLUE'>CDPRO - Cientista de Dados Profissional Especialista em IA</font>
#
# # <font color='GREY'> IA para realizar consultas em Bancos de Dados por meio de comandos textuais</font>

# %% [markdown]
# # Instalando e Importando a Biblioteca Python - Vanna

# %%
# %pip install vanna
# Out:
# Collecting vanna
#   Downloading vanna-0.0.38-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 859.2 kB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vanna) (2.31.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from vanna) (0.9.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from vanna) (5.15.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vanna) (1.5.3)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.10/dist-packages (from vanna) (0.4.4)
# Collecting kaleido (from vanna)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vanna) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vanna) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->vanna) (1.23.5)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->vanna) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly->vanna) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vanna) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vanna) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vanna) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vanna) (2023.11.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->vanna) (1.16.0)
# Installing collected packages: kaleido, vanna
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed kaleido-0.2.1 vanna-0.0.38

# %%
import vanna
from vanna.remote import VannaDefault

# %% [markdown]
# # Logar no Vanna
# O Vanna oferece uma função para obter uma chave de API. Você receberá um código enviado para o seu e-mail.
# Você pode salvar sua chave de API para uso futuro, assim você não precisará fazer login todas as vezes.

# %%
api_key = vanna.get_api_key('renatamontanhana@gmail.com')
# Out:
# Check your email for the code and enter it here: B8UFMP

# %% [markdown]
# # Base de Dados
# `chinook` é amplamente utilizada para ensino e demonstrações em gestão de banco de dados, consultas SQL e modelagem de dados. Ela representa uma loja de mídia digital, incluindo tabelas para artistas, álbuns, faixas de mídia, faturas e clientes, semelhante a uma loja iTunes do mundo real [Chinook database](https://www.sqlitetutorial.net/sqlite-sample-database/)

# %%
vanna_model_name = 'chinook'


vn = VannaDefault(model=vanna_model_name, api_key=api_key)

# %% [markdown]
# # Conectando na Base de Dados
# Aqui estamos nos conectando a um banco de dados SQLite, mas você pode se conectar **a qualquer** banco de dados SQL

# %%
vn.connect_to_sqlite('https://vanna.ai/Chinook.sqlite')

# %% [markdown]
# # Vamos Fazer A Mágica Acontecer
# Agora vamos usar vn.ask para fazer perguntas e isso irá gerar SQL, executar o SQL, mostrar a tabela e gerar um gráfico.

# %%
vn.ask("Quais são os top 3 artistas mais vendidos? ")
# Out:
# SELECT a.ArtistId, a.Name, SUM(il.Quantity) AS TotalVendas
# FROM Artist a
# JOIN Album al ON a.ArtistId = al.ArtistId
# JOIN Track t ON al.AlbumId = t.AlbumId
# JOIN InvoiceLine il ON t.TrackId = il.TrackId
# GROUP BY a.ArtistId, a.Name
# ORDER BY TotalVendas DESC
# LIMIT 3;
#    ArtistId         Name  TotalVendas
# 0        90  Iron Maiden          140
# 1       150           U2          107
# 2        50    Metallica           91

# %% [markdown]
# # Agora de acordo com as tabelas abaixo, faça uma nova pergunta
#
# Para referência, estas são as tabelas no banco de dados.
#
# <img style="max-width:400px" alt="" src="data:image/png;base64,...">

# %%
vn.ask('Qual o album mais comprada do U2?')
# Out:
# SELECT a.Title AS AlbumMaisComprado
# FROM Album a
# JOIN Artist ar ON a.ArtistId = ar.ArtistId
# JOIN Track t ON a.AlbumId = t.AlbumId
# JOIN InvoiceLine il ON t.TrackId = il.TrackId
# WHERE ar.Name = 'U2'
# GROUP BY a.Title
# ORDER BY SUM(il.Quantity) DESC
# LIMIT 1;
#   AlbumMaisComprado
# 0    Rattle And Hum

# %% [markdown]
# ## Aplicação WEB com Flask Python
# ![vanna-flask](https://vanna.ai/blog/img/vanna-flask.gif)

# %%
from vanna.flask import VannaFlaskApp
app = VannaFlaskApp(vn)
app.run()
